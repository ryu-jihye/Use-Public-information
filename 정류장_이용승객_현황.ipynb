# %% [markdown]
# <a href="https://colab.research.google.com/github/ryu-jihye/Use-Public-information/blob/main/%EC%A0%95%EB%A5%98%EC%9E%A5_%EC%9D%B4%EC%9A%A9%EC%8A%B9%EA%B0%9D_%ED%98%84%ED%99%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.Series([-3, 1, 3, 0, 5, -2, 7]).plot(title="테스트")
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5fe2a5c7-aa74-4226-9efb-309b158e38dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fe2a5c7-aa74-4226-9efb-309b158e38dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 한국교통안전공단_운수회사 교통사고 통계정보_20181231.csv to 한국교통안전공단_운수회사 교통사고 통계정보_20181231.csv

# %%
# %ls
# Out:
# '한국교통안전공단_운수회사 교통사고 통계정보_20181231.csv'   sample_data/
# '인천광역시_정류장별 이용승객 현황_20191231.csv'

# %%
af = pd.read_csv("인천광역시_정류장별 이용승객 현황_20191231.csv", encoding="cp949")
af.shape
# Out:
# (6155, 10)

# %%
pd.options.display.max_columns = 10

# %%
af.head()
# Out:
#     권역       정류소명  정류소ID  승차건수(총합계)   하차건수  승차건수(카드)  하차건수(카드)  승차건수(현금)  \
# 0   서구    (구)신현주공  42228     106476  74329    101822     74329      4654
# 1  부평구   (구)현대백화점  40158      92605  73256     90236     73256      2369
# 2   서구  (주)경동세라믹스  89146       5597    185      5469       185       128
# 3   서구   (주)경인양행앞  42096      13213  13552     12967     13552       246
# 4   서구   (주)경인양행앞  42097      24975  41148     24295     41148       680
#
#    일평균 승하차 건수 일평균 대당 승하차 건수
# 0      495.36          3.16
# 1      454.41         34.95
# 2       15.84          3.17
# 3       73.33          1.36
# 4      181.16          3.35

# %%
af.index
# Out:
# RangeIndex(start=0, stop=6155, step=1)

# %%
af.columns
# Out:
# Index(['권역', '정류소명', '정류소ID', '승차건수(총합계)', '하차건수', '승차건수(카드)', '하차건수(카드)',
#        '승차건수(현금)', '일평균 승하차 건수', '일평균 대당 승하차 건수'],
#       dtype='object')

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6155 entries, 0 to 6154
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   권역             6155 non-null   object
#  1   정류소명           6155 non-null   object
#  2   정류소ID          6155 non-null   object
#  3   승차건수(총합계)      6155 non-null   int64
#  4   하차건수           6155 non-null   int64
#  5   승차건수(카드)       6155 non-null   int64
#  6   하차건수(카드)       6155 non-null   int64
#  7   승차건수(현금)       6155 non-null   int64
#  8   일평균 승하차 건수     6155 non-null   float64
#  9   일평균 대당 승하차 건수  6155 non-null   object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 481.0+ KB

# %%
af.dtypes
# Out:
# 권역                object
# 정류소명              object
# 정류소ID             object
# 승차건수(총합계)          int64
# 하차건수               int64
# 승차건수(카드)           int64
# 하차건수(카드)           int64
# 승차건수(현금)           int64
# 일평균 승하차 건수       float64
# 일평균 대당 승하차 건수     object
# dtype: object

# %%
True == 1
# Out:
# True

# %%
n = af.isnull().sum() + 2
n
# Out:
# 권역               2
# 정류소명             2
# 정류소ID            2
# 승차건수(총합계)        2
# 하차건수             2
# 승차건수(카드)         2
# 하차건수(카드)         2
# 승차건수(현금)         2
# 일평균 승하차 건수       2
# 일평균 대당 승하차 건수    2
# dtype: int64

# %%
n.plot.bar()
#결측치 값 없음

# %%
n.sort_values().plot.barh(figsize=(7, 8))
#결측치 값 없음
